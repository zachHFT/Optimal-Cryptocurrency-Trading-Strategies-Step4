# %%
# %pip install python-binance 
#This package is not present in the standard library databases, need to pip install it
# Out:
# Requirement already satisfied: python-binance in c:\users\liuye\anaconda3\envs\work\lib\site-packages (1.0.15)
# Requirement already satisfied: requests in c:\users\liuye\anaconda3\envs\work\lib\site-packages (from python-binance) (2.25.1)
# Requirement already satisfied: six in c:\users\liuye\anaconda3\envs\work\lib\site-packages (from python-binance) (1.15.0)
# Requirement already satisfied: aiohttp in c:\users\liuye\anaconda3\envs\work\lib\site-packages (from python-binance) (3.7.4)
# Requirement already satisfied: dateparser in c:\users\liuye\anaconda3\envs\work\lib\site-packages (from python-binance) (1.1.0)
# Requirement already satisfied: ujson in c:\users\liuye\anaconda3\envs\work\lib\site-packages (from python-binance) (4.2.0)
# Requirement already satisfied: websockets==9.1 in c:\users\liuye\anaconda3\envs\work\lib\site-packages (from python-binance) (9.1)
# Requirement already satisfied: chardet<4.0,>=2.0 in c:\users\liuye\anaconda3\envs\work\lib\site-packages (from aiohttp->python-binance) (3.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\liuye\anaconda3\envs\work\lib\site-packages (from aiohttp->python-binance) (1.6.3)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\liuye\anaconda3\envs\work\lib\site-packages (from aiohttp->python-binance) (20.3.0)
# Requirement already satisfied: async-timeout<4.0,>=3.0 in c:\users\liuye\anaconda3\envs\work\lib\site-packages (from aiohttp->python-binance) (3.0.1)
# Requirement already satisfied: typing-extensions>=3.6.5 in c:\users\liuye\anaconda3\envs\work\lib\site-packages (from aiohttp->python-binance) (3.7.4.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\liuye\anaconda3\envs\work\lib\site-packages (from aiohttp->python-binance) (5.1.0)
# Requirement already satisfied: idna>=2.0 in c:\users\liuye\anaconda3\envs\work\lib\site-packages (from yarl<2.0,>=1.0->aiohttp->python-binance) (2.10)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27 in c:\users\liuye\anaconda3\envs\work\lib\site-packages (from dateparser->python-binance) (2021.11.10)
# Requirement already satisfied: python-dateutil in c:\users\liuye\anaconda3\envs\work\lib\site-packages (from dateparser->python-binance) (2.8.1)
# Requirement already satisfied: pytz in c:\users\liuye\anaconda3\envs\work\lib\site-packages (from dateparser->python-binance) (2021.1)
# Requirement already satisfied: tzlocal in c:\users\liuye\anaconda3\envs\work\lib\site-packages (from dateparser->python-binance) (4.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\liuye\anaconda3\envs\work\lib\site-packages (from requests->python-binance) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\liuye\anaconda3\envs\work\lib\site-packages (from requests->python-binance) (2021.10.8)
# Requirement already satisfied: tzdata in c:\users\liuye\anaconda3\envs\work\lib\site-packages (from tzlocal->dateparser->python-binance) (2021.5)
# Requirement already satisfied: backports.zoneinfo in c:\users\liuye\anaconda3\envs\work\lib\site-packages (from tzlocal->dateparser->python-binance) (0.2.1)
# Requirement already satisfied: pytz-deprecation-shim in c:\users\liuye\anaconda3\envs\work\lib\site-packages (from tzlocal->dateparser->python-binance) (0.1.0.post0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# IMPORTS
import pandas as pd
import math
import os.path
from datetime import datetime
from datetime import date
from dateutil import parser
import pickle
import asyncio
from datetime import timedelta
import dateutil.parser
import imp
import json

from binance.client import Client

#import api #You need to create your own api.py file which contains the api keys
import get_uptodate_binance_data

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\liuye\\ForPython\\Optimal-Cryptocurrency-Trading-Strategies-Step2\\Webscrapping\\Medium'

# %%
#imp.reload(api)
imp.reload(get_uptodate_binance_data)
# Out:
# <module 'get_uptodate_binance_data' from 'C:\\Users\\liuye\\ForPython\\Optimal-Cryptocurrency-Trading-Strategies-Step2\\Webscrapping\\Medium\\get_uptodate_binance_data.py'>

# %%
# os.chdir('/root/') #Do not forget to set yourself within the correct directory you wish to work in

# %%
with open('data_core.json') as json_file: #Open and Load the data_core json file which is gives is a structured repo of all our .csv data files
    data_core = json.load(json_file)

# %%
print(json.dumps(data_core, indent=4)) #to see the structure of the json file
# Out:
# {
#     "USDT": {
#         "BTCUSDT": {
#             "1d": {
#                 "trading_starting_date": "2017-08-17 00:00:00",
#                 "file_end_date": "14 Nov 2021 00:00:00",
#                 "csv_filename": "BTCUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2017-08-17 04:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "BTCUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2017-08-17 04:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "BTCUSDT-5m-binance.csv"
#             },
#             "1m": {
#                 "trading_starting_date": "2017-08-17 04:00:00",
#                 "file_end_date": "10 Aug 2021 00:00:00",
#                 "csv_filename": "BTCUSDT-1m-binance.csv"
#             }
#         },
#         "ETHUSDT": {
#             "1d": {
#                 "trading_starting_date": "2017-08-17 00:00:00",
#                 "file_end_date": "14 Nov 2021 00:00:00",
#                 "csv_filename": "ETHUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2017-08-17 04:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "ETHUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2017-08-17 04:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "ETHUSDT-5m-binance.csv"
#             },
#             "1m": {
#                 "trading_starting_date": "2017-08-17 04:00:00",
#                 "file_end_date": "10 Aug 2021 00:00:00",
#                 "csv_filename": "ETHUSDT-1m-binance.csv"
#             }
#         },
#         "BNBUSDT": {
#             "1d": {
#                 "trading_starting_date": "2017-11-06 00:00:00",
#                 "file_end_date": "14 Nov 2021 00:00:00",
#                 "csv_filename": "BNBUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2017-11-06 03:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "BNBUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2017-11-06 03:50:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "BNBUSDT-5m-binance.csv"
#             },
#             "1m": {
#                 "trading_starting_date": "2017-11-06 03:54:00",
#                 "file_end_date": "10 Aug 2021 00:00:00",
#                 "csv_filename": "BNBUSDT-1m-binance.csv"
#             }
#         },
#         "NEOUSDT": {
#             "1d": {
#                 "trading_starting_date": "2017-11-20 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "NEOUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2017-11-20 03:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "NEOUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2017-11-20 03:40:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "NEOUSDT-5m-binance.csv"
#             },
#             "1m": {}
#         },
#         "LTCUSDT": {
#             "1d": {
#                 "trading_starting_date": "2017-12-13 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "LTCUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2017-12-13 03:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "LTCUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2017-12-13 03:30:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "LTCUSDT-5m-binance.csv"
#             },
#             "1m": {}
#         },
#         "QTUMUSDT": {
#             "1d": {
#                 "trading_starting_date": "2018-03-19 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "QTUMUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2018-03-19 08:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "QTUMUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2018-03-19 08:45:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "QTUMUSDT-5m-binance.csv"
#             }
#         },
#         "ADAUSDT": {
#             "1d": {
#                 "trading_starting_date": "2018-04-17 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "ADAUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2018-04-17 04:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "ADAUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2018-04-17 04:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "ADAUSDT-5m-binance.csv"
#             }
#         },
#         "XRPUSDT": {
#             "1d": {
#                 "trading_starting_date": "2018-05-04 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "XRPUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2018-05-04 08:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "XRPUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2018-05-04 08:10:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "XRPUSDT-5m-binance.csv"
#             }
#         },
#         "EOSUSDT": {
#             "1d": {
#                 "trading_starting_date": "2018-05-28 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "EOSUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2018-05-28 05:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "EOSUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2018-05-28 05:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "EOSUSDT-5m-binance.csv"
#             }
#         },
#         "TUSDUSDT": {
#             "1d": {
#                 "trading_starting_date": "2018-05-31 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "TUSDUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2018-05-31 09:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "TUSDUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2018-05-31 09:30:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "TUSDUSDT-5m-binance.csv"
#             }
#         },
#         "IOTAUSDT": {
#             "1d": {
#                 "trading_starting_date": "2018-05-31 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "IOTAUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2018-05-31 09:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "IOTAUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2018-05-31 09:30:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "IOTAUSDT-5m-binance.csv"
#             }
#         },
#         "XLMUSDT": {
#             "1d": {
#                 "trading_starting_date": "2018-05-31 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "XLMUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2018-05-31 09:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "XLMUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2018-05-31 09:30:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "XLMUSDT-5m-binance.csv"
#             }
#         },
#         "ONTUSDT": {
#             "1d": {
#                 "trading_starting_date": "2018-06-08 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "ONTUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2018-06-08 07:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "ONTUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2018-06-08 07:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "ONTUSDT-5m-binance.csv"
#             }
#         },
#         "TRXUSDT": {
#             "1d": {
#                 "trading_starting_date": "2018-06-11 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "TRXUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2018-06-11 11:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "TRXUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2018-06-11 11:30:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "TRXUSDT-5m-binance.csv"
#             }
#         },
#         "ETCUSDT": {
#             "1d": {
#                 "trading_starting_date": "2018-06-12 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "ETCUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2018-06-12 02:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "ETCUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2018-06-12 02:30:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "ETCUSDT-5m-binance.csv"
#             }
#         },
#         "ICXUSDT": {
#             "1d": {
#                 "trading_starting_date": "2018-06-13 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "ICXUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2018-06-13 08:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "ICXUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2018-06-13 08:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "ICXUSDT-5m-binance.csv"
#             }
#         },
#         "NULSUSDT": {
#             "1d": {
#                 "trading_starting_date": "2018-07-23 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "NULSUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2018-07-23 04:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "NULSUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2018-07-23 04:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "NULSUSDT-5m-binance.csv"
#             }
#         },
#         "VETUSDT": {
#             "1d": {
#                 "trading_starting_date": "2018-07-25 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "VETUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2018-07-25 04:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "VETUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2018-07-25 04:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "VETUSDT-5m-binance.csv"
#             }
#         },
#         "PAXUSDT": {
#             "1d": {
#                 "trading_starting_date": "2018-10-04 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "PAXUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2018-10-04 10:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "PAXUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2018-10-04 10:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "PAXUSDT-5m-binance.csv"
#             }
#         },
#         "USDCUSDT": {
#             "1d": {
#                 "trading_starting_date": "2018-12-15 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "USDCUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2018-12-15 03:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "USDCUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2018-12-15 03:10:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "USDCUSDT-5m-binance.csv"
#             }
#         },
#         "LINKUSDT": {
#             "1d": {
#                 "trading_starting_date": "2019-01-16 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "LINKUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2019-01-16 10:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "LINKUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2019-01-16 10:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "LINKUSDT-5m-binance.csv"
#             }
#         },
#         "WAVESUSDT": {
#             "1d": {
#                 "trading_starting_date": "2019-01-18 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "WAVESUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2019-01-18 10:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "WAVESUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2019-01-18 10:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "WAVESUSDT-5m-binance.csv"
#             }
#         },
#         "BTTUSDT": {
#             "1d": {
#                 "trading_starting_date": "2019-01-31 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "BTTUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2019-01-31 10:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "BTTUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2019-01-31 10:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "BTTUSDT-5m-binance.csv"
#             }
#         },
#         "ONGUSDT": {
#             "1d": {
#                 "trading_starting_date": "2019-02-16 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "ONGUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2019-02-16 10:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "ONGUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2019-02-16 10:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "ONGUSDT-5m-binance.csv"
#             }
#         },
#         "HOTUSDT": {
#             "1d": {
#                 "trading_starting_date": "2019-02-18 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "HOTUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2019-02-18 10:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "HOTUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2019-02-18 10:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "HOTUSDT-5m-binance.csv"
#             }
#         },
#         "ZILUSDT": {
#             "1d": {
#                 "trading_starting_date": "2019-02-19 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "ZILUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2019-02-19 11:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "ZILUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2019-02-19 11:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "ZILUSDT-5m-binance.csv"
#             }
#         },
#         "ZRXUSDT": {
#             "1d": {
#                 "trading_starting_date": "2019-02-28 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "ZRXUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2019-02-28 04:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "ZRXUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2019-02-28 04:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "ZRXUSDT-5m-binance.csv"
#             }
#         },
#         "FETUSDT": {
#             "1d": {
#                 "trading_starting_date": "2019-02-28 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "FETUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2019-02-28 10:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "FETUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2019-02-28 10:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "FETUSDT-5m-binance.csv"
#             }
#         },
#         "BATUSDT": {
#             "1d": {
#                 "trading_starting_date": "2019-03-04 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "BATUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2019-03-04 10:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "BATUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2019-03-04 10:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "BATUSDT-5m-binance.csv"
#             }
#         },
#         "XMRUSDT": {
#             "1d": {
#                 "trading_starting_date": "2019-03-15 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "XMRUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2019-03-15 04:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "XMRUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2019-03-15 04:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "XMRUSDT-5m-binance.csv"
#             }
#         },
#         "ZECUSDT": {
#             "1d": {
#                 "trading_starting_date": "2019-03-21 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "ZECUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2019-03-21 04:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "ZECUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2019-03-21 04:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "ZECUSDT-5m-binance.csv"
#             }
#         },
#         "IOSTUSDT": {
#             "1d": {
#                 "trading_starting_date": "2019-03-22 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "IOSTUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2019-03-22 04:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "IOSTUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2019-03-22 04:05:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "IOSTUSDT-5m-binance.csv"
#             }
#         },
#         "CELRUSDT": {
#             "1d": {
#                 "trading_starting_date": "2019-03-25 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "CELRUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2019-03-25 04:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "CELRUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2019-03-25 04:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "CELRUSDT-5m-binance.csv"
#             }
#         },
#         "DASHUSDT": {
#             "1d": {
#                 "trading_starting_date": "2019-03-28 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "DASHUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2019-03-28 04:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "DASHUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2019-03-28 04:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "DASHUSDT-5m-binance.csv"
#             }
#         },
#         "NANOUSDT": {
#             "1d": {
#                 "trading_starting_date": "2019-04-03 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "NANOUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2019-04-03 04:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "NANOUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2019-04-03 04:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "NANOUSDT-5m-binance.csv"
#             }
#         },
#         "OMGUSDT": {
#             "1d": {
#                 "trading_starting_date": "2019-04-03 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "OMGUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2019-04-03 04:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "OMGUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2019-04-03 04:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "OMGUSDT-5m-binance.csv"
#             }
#         },
#         "THETAUSDT": {
#             "1d": {
#                 "trading_starting_date": "2019-04-10 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "THETAUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2019-04-10 04:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "THETAUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2019-04-10 04:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "THETAUSDT-5m-binance.csv"
#             }
#         },
#         "ENJUSDT": {
#             "1d": {
#                 "trading_starting_date": "2019-04-18 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "ENJUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2019-04-18 04:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "ENJUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2019-04-18 04:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "ENJUSDT-5m-binance.csv"
#             }
#         },
#         "MITHUSDT": {
#             "1d": {
#                 "trading_starting_date": "2019-04-19 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "MITHUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2019-04-19 10:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "MITHUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2019-04-19 10:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "MITHUSDT-5m-binance.csv"
#             }
#         },
#         "MATICUSDT": {
#             "1d": {
#                 "trading_starting_date": "2019-04-26 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "MATICUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2019-04-26 15:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "MATICUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2019-04-26 15:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "MATICUSDT-5m-binance.csv"
#             }
#         },
#         "ATOMUSDT": {
#             "1d": {
#                 "trading_starting_date": "2019-04-29 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "ATOMUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2019-04-29 04:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "ATOMUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2019-04-29 04:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "ATOMUSDT-5m-binance.csv"
#             }
#         },
#         "TFUELUSDT": {
#             "1d": {
#                 "trading_starting_date": "2019-05-24 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "TFUELUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2019-05-24 10:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "TFUELUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2019-05-24 10:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "TFUELUSDT-5m-binance.csv"
#             }
#         },
#         "ONEUSDT": {
#             "1d": {
#                 "trading_starting_date": "2019-06-01 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "ONEUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2019-06-01 04:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "ONEUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2019-06-01 04:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "ONEUSDT-5m-binance.csv"
#             }
#         },
#         "FTMUSDT": {
#             "1d": {
#                 "trading_starting_date": "2019-06-11 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "FTMUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2019-06-11 04:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "FTMUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2019-06-11 04:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "FTMUSDT-5m-binance.csv"
#             }
#         },
#         "ALGOUSDT": {
#             "1d": {
#                 "trading_starting_date": "2019-06-22 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "ALGOUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2019-06-22 00:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "ALGOUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2019-06-22 00:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "ALGOUSDT-5m-binance.csv"
#             }
#         },
#         "GTOUSDT": {
#             "1d": {
#                 "trading_starting_date": "2019-07-01 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "GTOUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2019-07-01 11:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "GTOUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2019-07-01 11:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "GTOUSDT-5m-binance.csv"
#             }
#         },
#         "DOGEUSDT": {
#             "1d": {
#                 "trading_starting_date": "2019-07-05 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "DOGEUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2019-07-05 12:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "DOGEUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2019-07-05 12:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "DOGEUSDT-5m-binance.csv"
#             }
#         },
#         "DUSKUSDT": {
#             "1d": {
#                 "trading_starting_date": "2019-07-22 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "DUSKUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2019-07-22 10:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "DUSKUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2019-07-22 10:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "DUSKUSDT-5m-binance.csv"
#             }
#         },
#         "ANKRUSDT": {
#             "1d": {
#                 "trading_starting_date": "2019-07-23 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "ANKRUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2019-07-23 14:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "ANKRUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2019-07-23 14:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "ANKRUSDT-5m-binance.csv"
#             }
#         },
#         "WINUSDT": {
#             "1d": {
#                 "trading_starting_date": "2019-08-01 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "WINUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2019-08-01 10:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "WINUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2019-08-01 10:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "WINUSDT-5m-binance.csv"
#             }
#         },
#         "COSUSDT": {
#             "1d": {
#                 "trading_starting_date": "2019-08-03 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "COSUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2019-08-03 10:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "COSUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2019-08-03 10:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "COSUSDT-5m-binance.csv"
#             }
#         },
#         "COCOSUSDT": {
#             "1d": {
#                 "trading_starting_date": "2019-08-21 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "COCOSUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2019-08-21 11:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "COCOSUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2019-08-21 11:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "COCOSUSDT-5m-binance.csv"
#             }
#         },
#         "MTLUSDT": {
#             "1d": {
#                 "trading_starting_date": "2019-08-23 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "MTLUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2019-08-23 10:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "MTLUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2019-08-23 10:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "MTLUSDT-5m-binance.csv"
#             }
#         },
#         "TOMOUSDT": {
#             "1d": {
#                 "trading_starting_date": "2019-08-24 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "TOMOUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2019-08-24 13:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "TOMOUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2019-08-24 13:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "TOMOUSDT-5m-binance.csv"
#             }
#         },
#         "PERLUSDT": {
#             "1d": {
#                 "trading_starting_date": "2019-08-26 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "PERLUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2019-08-26 12:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "PERLUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2019-08-26 12:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "PERLUSDT-5m-binance.csv"
#             }
#         },
#         "DENTUSDT": {
#             "1d": {
#                 "trading_starting_date": "2019-08-27 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "DENTUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2019-08-27 04:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "DENTUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2019-08-27 04:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "DENTUSDT-5m-binance.csv"
#             }
#         },
#         "MFTUSDT": {
#             "1d": {
#                 "trading_starting_date": "2019-08-27 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "MFTUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2019-08-27 04:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "MFTUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2019-08-27 04:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "MFTUSDT-5m-binance.csv"
#             }
#         },
#         "KEYUSDT": {
#             "1d": {
#                 "trading_starting_date": "2019-08-27 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "KEYUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2019-08-27 04:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "KEYUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2019-08-27 04:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "KEYUSDT-5m-binance.csv"
#             }
#         },
#         "DOCKUSDT": {
#             "1d": {
#                 "trading_starting_date": "2019-08-27 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "DOCKUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2019-08-27 04:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "DOCKUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2019-08-27 04:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "DOCKUSDT-5m-binance.csv"
#             }
#         },
#         "WANUSDT": {
#             "1d": {
#                 "trading_starting_date": "2019-08-27 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "WANUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2019-08-27 04:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "WANUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2019-08-27 04:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "WANUSDT-5m-binance.csv"
#             }
#         },
#         "FUNUSDT": {
#             "1d": {
#                 "trading_starting_date": "2019-08-27 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "FUNUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2019-08-27 04:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "FUNUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2019-08-27 04:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "FUNUSDT-5m-binance.csv"
#             }
#         },
#         "CVCUSDT": {
#             "1d": {
#                 "trading_starting_date": "2019-08-27 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "CVCUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2019-08-27 04:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "CVCUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2019-08-27 04:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "CVCUSDT-5m-binance.csv"
#             }
#         },
#         "CHZUSDT": {
#             "1d": {
#                 "trading_starting_date": "2019-09-06 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "CHZUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2019-09-06 04:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "CHZUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2019-09-06 04:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "CHZUSDT-5m-binance.csv"
#             }
#         },
#         "BANDUSDT": {
#             "1d": {
#                 "trading_starting_date": "2019-09-18 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "BANDUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2019-09-18 12:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "BANDUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2019-09-18 12:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "BANDUSDT-5m-binance.csv"
#             }
#         },
#         "BUSDUSDT": {
#             "1d": {
#                 "trading_starting_date": "2019-09-20 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "BUSDUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2019-09-20 08:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "BUSDUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2019-09-20 08:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "BUSDUSDT-5m-binance.csv"
#             }
#         },
#         "BEAMUSDT": {
#             "1d": {
#                 "trading_starting_date": "2019-09-21 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "BEAMUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2019-09-21 12:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "BEAMUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2019-09-21 12:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "BEAMUSDT-5m-binance.csv"
#             }
#         },
#         "XTZUSDT": {
#             "1d": {
#                 "trading_starting_date": "2019-09-24 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "XTZUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2019-09-24 11:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "XTZUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2019-09-24 11:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "XTZUSDT-5m-binance.csv"
#             }
#         },
#         "RENUSDT": {
#             "1d": {
#                 "trading_starting_date": "2019-09-25 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "RENUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2019-09-25 12:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "RENUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2019-09-25 12:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "RENUSDT-5m-binance.csv"
#             }
#         },
#         "RVNUSDT": {
#             "1d": {
#                 "trading_starting_date": "2019-09-25 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "RVNUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2019-09-25 12:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "RVNUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2019-09-25 12:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "RVNUSDT-5m-binance.csv"
#             }
#         },
#         "HBARUSDT": {
#             "1d": {
#                 "trading_starting_date": "2019-09-29 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "HBARUSDT-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2019-09-29 04:00:00",
#                 "file_end_date": "02 Aug 2021 00:00:00",
#                 "csv_filename": "HBARUSDT-1h-binance.csv"
#             },
#             "5m": {
#                 "trading_starting_date": "2019-09-29 04:00:00",
#                 "file_end_date": "03 Aug 2021 00:00:00",
#                 "csv_filename": "HBARUSDT-5m-binance.csv"
#             }
#         },
#         "NKNUSDT": {
#             "1d": {
#                 "trading_starting_date": "2019-10-11 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "NKNUSDT-1d-binance.csv"
#             },
#             "1h": {
# ...
#             }
#         },
#         "CAKEBNB": {
#             "1d": {
#                 "trading_starting_date": "2020-09-29 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "CAKEBNB-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2020-09-29 08:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "CAKEBNB-1h-binance.csv"
#             }
#         },
#         "SPARTABNB": {
#             "1d": {
#                 "trading_starting_date": "2020-09-29 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "SPARTABNB-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2020-09-29 08:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "SPARTABNB-1h-binance.csv"
#             }
#         },
#         "XVSBNB": {
#             "1d": {
#                 "trading_starting_date": "2020-10-06 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "XVSBNB-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2020-10-06 05:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "XVSBNB-1h-binance.csv"
#             }
#         },
#         "ALPHABNB": {
#             "1d": {
#                 "trading_starting_date": "2020-10-10 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "ALPHABNB-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2020-10-10 05:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "ALPHABNB-1h-binance.csv"
#             }
#         },
#         "AAVEBNB": {
#             "1d": {
#                 "trading_starting_date": "2020-10-15 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "AAVEBNB-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2020-10-15 03:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "AAVEBNB-1h-binance.csv"
#             }
#         },
#         "NEARBNB": {
#             "1d": {
#                 "trading_starting_date": "2020-10-14 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "NEARBNB-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2020-10-14 05:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "NEARBNB-1h-binance.csv"
#             }
#         },
#         "FILBNB": {
#             "1d": {
#                 "trading_starting_date": "2020-10-15 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "FILBNB-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2020-10-15 17:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "FILBNB-1h-binance.csv"
#             }
#         },
#         "INJBNB": {
#             "1d": {
#                 "trading_starting_date": "2020-10-21 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "INJBNB-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2020-10-21 04:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "INJBNB-1h-binance.csv"
#             }
#         },
#         "CTKBNB": {
#             "1d": {
#                 "trading_starting_date": "2020-10-27 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "CTKBNB-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2020-10-27 08:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "CTKBNB-1h-binance.csv"
#             }
#         },
#         "KP3RBNB": {
#             "1d": {
#                 "trading_starting_date": "2020-11-03 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "KP3RBNB-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2020-11-03 12:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "KP3RBNB-1h-binance.csv"
#             }
#         },
#         "AXSBNB": {
#             "1d": {
#                 "trading_starting_date": "2020-11-04 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "AXSBNB-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2020-11-04 13:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "AXSBNB-1h-binance.csv"
#             }
#         },
#         "HARDBNB": {
#             "1d": {
#                 "trading_starting_date": "2020-11-06 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "HARDBNB-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2020-11-06 06:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "HARDBNB-1h-binance.csv"
#             }
#         },
#         "UNFIBNB": {
#             "1d": {
#                 "trading_starting_date": "2020-11-19 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "UNFIBNB-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2020-11-19 06:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "UNFIBNB-1h-binance.csv"
#             }
#         },
#         "PROMBNB": {
#             "1d": {
#                 "trading_starting_date": "2020-11-26 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "PROMBNB-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2020-11-26 07:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "PROMBNB-1h-binance.csv"
#             }
#         },
#         "BIFIBNB": {
#             "1d": {
#                 "trading_starting_date": "2021-03-16 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "BIFIBNB-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2021-03-16 09:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "BIFIBNB-1h-binance.csv"
#             }
#         },
#         "ICPBNB": {
#             "1d": {
#                 "trading_starting_date": "2021-05-11 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "ICPBNB-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2021-05-11 01:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "ICPBNB-1h-binance.csv"
#             }
#         },
#         "ARBNB": {
#             "1d": {
#                 "trading_starting_date": "2021-05-14 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "ARBNB-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2021-05-14 12:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "ARBNB-1h-binance.csv"
#             }
#         },
#         "POLSBNB": {
#             "1d": {
#                 "trading_starting_date": "2021-05-19 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "POLSBNB-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2021-05-19 07:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "POLSBNB-1h-binance.csv"
#             }
#         },
#         "MDXBNB": {
#             "1d": {
#                 "trading_starting_date": "2021-05-24 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "MDXBNB-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2021-05-24 09:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "MDXBNB-1h-binance.csv"
#             }
#         },
#         "MASKBNB": {
#             "1d": {
#                 "trading_starting_date": "2021-05-25 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "MASKBNB-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2021-05-25 06:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "MASKBNB-1h-binance.csv"
#             }
#         },
#         "LPTBNB": {
#             "1d": {
#                 "trading_starting_date": "2021-05-28 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "LPTBNB-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2021-05-28 05:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "LPTBNB-1h-binance.csv"
#             }
#         },
#         "NUBNB": {
#             "1d": {
#                 "trading_starting_date": "2021-06-04 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "NUBNB-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2021-06-04 05:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "NUBNB-1h-binance.csv"
#             }
#         },
#         "ATABNB": {
#             "1d": {
#                 "trading_starting_date": "2021-06-07 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "ATABNB-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2021-06-07 06:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "ATABNB-1h-binance.csv"
#             }
#         },
#         "GTCBNB": {
#             "1d": {
#                 "trading_starting_date": "2021-06-10 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "GTCBNB-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2021-06-10 10:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "GTCBNB-1h-binance.csv"
#             }
#         },
#         "TORNBNB": {
#             "1d": {
#                 "trading_starting_date": "2021-06-11 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "TORNBNB-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2021-06-11 06:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "TORNBNB-1h-binance.csv"
#             }
#         },
#         "KEEPBNB": {
#             "1d": {
#                 "trading_starting_date": "2021-06-17 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "KEEPBNB-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2021-06-17 06:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "KEEPBNB-1h-binance.csv"
#             }
#         },
#         "ERNBNB": {
#             "1d": {
#                 "trading_starting_date": "2021-06-22 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "ERNBNB-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2021-06-22 06:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "ERNBNB-1h-binance.csv"
#             }
#         },
#         "KLAYBNB": {
#             "1d": {
#                 "trading_starting_date": "2021-06-24 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "KLAYBNB-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2021-06-24 08:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "KLAYBNB-1h-binance.csv"
#             }
#         },
#         "BONDBNB": {
#             "1d": {
#                 "trading_starting_date": "2021-07-05 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "BONDBNB-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2021-07-05 06:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "BONDBNB-1h-binance.csv"
#             }
#         },
#         "MLNBNB": {
#             "1d": {
#                 "trading_starting_date": "2021-07-05 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "MLNBNB-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2021-07-05 06:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "MLNBNB-1h-binance.csv"
#             }
#         },
#         "QUICKBNB": {
#             "1d": {
#                 "trading_starting_date": "2021-07-23 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "QUICKBNB-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2021-07-23 08:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "QUICKBNB-1h-binance.csv"
#             }
#         },
#         "C98BNB": {
#             "1d": {
#                 "trading_starting_date": "2021-07-23 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "C98BNB-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2021-07-23 12:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "C98BNB-1h-binance.csv"
#             }
#         },
#         "CLVBNB": {
#             "1d": {
#                 "trading_starting_date": "2021-07-29 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "CLVBNB-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2021-07-29 06:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "CLVBNB-1h-binance.csv"
#             }
#         },
#         "QNTBNB": {
#             "1d": {
#                 "trading_starting_date": "2021-07-29 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "QNTBNB-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2021-07-29 06:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "QNTBNB-1h-binance.csv"
#             }
#         },
#         "FLOWBNB": {
#             "1d": {
#                 "trading_starting_date": "2021-07-30 00:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "FLOWBNB-1d-binance.csv"
#             },
#             "1h": {
#                 "trading_starting_date": "2021-07-30 13:00:00",
#                 "file_end_date": "01 Aug 2021 00:00:00",
#                 "csv_filename": "FLOWBNB-1h-binance.csv"
#             }
#         }
#     }
# }

# %% [markdown]
# # Get Up-to-date Data

# %%
# %%time
get_uptodate_binance_data.update_data_for_basepair(base_pair='USDT', nb_symbols_limit=5, bin_size='1d') 
'''Download all tradeable (i.e. active) pairs for the base pair 'USDT' with bin_size ('1d', '1h', '5m', '1m').
If you want only 10 pairs of data, set nb_symbols_limit=10
Note: Downloading all '1m' (1 minutes ) data will likely crash your computer unless you run it onto a powerful machine. 
I would advise starting with '1d' (1 day) data.'''
# Out:
# Downloading '0' minutes of new data available for 'BTCUSDT', i.e. '0' instances of '1d' data.
# All caught up..!
# Downloading '0' minutes of new data available for 'ETHUSDT', i.e. '0' instances of '1d' data.
# All caught up..!
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <timed exec> in <module>
#
# ~\ForPython\Optimal-Cryptocurrency-Trading-Strategies-Step2\Webscrapping\Medium\get_uptodate_binance_data.py in update_data_for_basepair(base_pair, nb_symbols_limit, bin_size)
#     156             #binsizes = {"1m": 1, "5m": 5, "1h": 60, "1d": 1440}
#     157             filename = get_all_binance(symbol, bin_size, start=start_date, end=end_date, save=True)
# --> 158             df = clean_csv(filename)
#     159             add_infos_to_data_core(base_pair, df, data_core, symbol, filename, bin_size)
#     160
#
# ~\ForPython\Optimal-Cryptocurrency-Trading-Strategies-Step2\Webscrapping\Medium\get_uptodate_binance_data.py in clean_csv(filename)
#      86 """ Clean the newly updated csv. In particular, we setup timestamp in datetime format, and we select a subset of the columns. We also make sure the data is one group of consecutive date, i.e. there is no other missing dates. """
#      87 def clean_csv(filename):
# ---> 88     df = pd.read_csv(main_directory+'/Data/Binance_OHLC'+'/'+filename)
#      89     df['timestamp'] = pd.to_datetime(df['timestamp'])
#      90     df['time_diff_in_days'] = df.timestamp.diff().dt.days
#
# ~\anaconda3\envs\work\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# ~\anaconda3\envs\work\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# ~\anaconda3\envs\work\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# ~\anaconda3\envs\work\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# ~\anaconda3\envs\work\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1865
#    1866         # open handles
# -> 1867         self._open_handles(src, kwds)
#    1868         assert self.handles is not None
#    1869         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# ~\anaconda3\envs\work\lib\site-packages\pandas\io\parsers.py in _open_handles(self, src, kwds)
#    1366             compression=kwds.get("compression", None),
#    1367             memory_map=kwds.get("memory_map", False),
# -> 1368             storage_options=kwds.get("storage_options", None),
#    1369         )
#    1370
#
# ~\anaconda3\envs\work\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     645                 encoding=ioargs.encoding,
#     646                 errors=errors,
# --> 647                 newline="",
#     648             )
#     649         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/liuye/ForPython/Optimal-Cryptocurrency-Trading-Strategies-Step2/Webscrapping/Medium/Data/Binance_OHLC/ETHUSDT-1d-binance.csv'

# %%
get_uptodate_binance_data.get_all_binance(symbol='KNCUSDT',
                                          kline_size='1d',
                                          start='12 Jun 2020',
                                          end='16 Nov 2021', save=True)
# Out:
# Downloading all available '1d' data for 'KNCUSDT'. Wait for a bit..!
# All caught up..!
# 'KNCUSDT-1d-binance.csv'

# %%
df = pd.read_csv('KNCUSDT-1h-binance.csv')

# %%
df
# Out:
#                  timestamp   open   high    low  close      volume  \
# 0      2020-06-12 08:00:00  1.154  1.279  1.122  1.198   54603.770
# 1      2020-06-12 09:00:00  1.199  1.211  1.181  1.181   23114.889
# 2      2020-06-12 10:00:00  1.191  1.201  1.176  1.180   80262.477
# 3      2020-06-12 11:00:00  1.183  1.227  1.171  1.191   43744.381
# 4      2020-06-12 12:00:00  1.188  1.212  1.162  1.191   72788.377
# ...                    ...    ...    ...    ...    ...         ...
# 12495  2021-11-15 20:00:00  1.902  1.909  1.894  1.896   73427.800
# 12496  2021-11-15 21:00:00  1.896  1.908  1.868  1.903   66248.100
# 12497  2021-11-15 22:00:00  1.905  1.917  1.883  1.914   87687.900
# 12498  2021-11-15 23:00:00  1.916  1.916  1.891  1.895   55733.300
# 12499  2021-11-16 00:00:00  1.896  1.897  1.811  1.820  349379.600
#
#           close_time       quote_av  trades  tb_base_av    tb_quote_av  ignore
# 0      1591952399999   66907.093700     211   19461.552   23993.239288       0
# 1      1591955999999   27541.001157     112    7337.215    8767.344616       0
# 2      1591959599999   95674.611314     309   33183.439   39535.763201       0
# 3      1591963199999   52424.449289     198   18994.484   22833.471008       0
# 4      1591966799999   86291.159374     311   37645.021   44516.754709       0
# ...              ...            ...     ...         ...            ...     ...
# 12495  1637009999999  139687.022500     670   41059.500   78143.599400       0
# 12496  1637013599999  124873.651000     571   26434.300   49891.879400       0
# 12497  1637017199999  166921.540100     669   39376.500   75049.728200       0
# 12498  1637020799999  106197.905300     451   26587.900   50659.537000       0
# 12499  1637024399999  643443.887900    2877  175141.200  322415.808800       0
#
# [12500 rows x 12 columns]
